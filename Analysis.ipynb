# %%
#importing relevant modules for analysis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#Loading the first dataset
df=pd.read_csv("C:/Users/Sally/Documents/Playstore_Data_Analysis/datasets/googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df.tail(2)
# Out:
#                                                  App             Category  \
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# 10839     Mature 17+  Books & Reference    19-Jan-15  Varies with device
# 10840       Everyone          Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 10839  Varies with device
# 10840  Varies with device

# %%
#length of dataset
dlength=len(df)
print(dlength)
# Out:
# 10841

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     4.5       38                 53M       5,000+  Free     0
# 10837     5.0        4                3.6M         100+  Free     0
# 10838     NaN        3                9.5M       1,000+  Free     0
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
#remove all duplicates in the dataset
df_clean = df.drop_duplicates(keep=False)
df_length=len(df_clean)
print(df_length)
# Out:
# 9948

# %%
df_clean.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     4.5       38                 53M       5,000+  Free     0
# 10837     5.0        4                3.6M         100+  Free     0
# 10838     NaN        3                9.5M       1,000+  Free     0
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
#removing irrelevant columns
df_clean.drop(['App','Last Updated','Current Ver'],axis=1,inplace=True)
df_clean.head()
# Out:
# C:\Users\Sally\AppData\Local\Temp\ipykernel_8580\1825962246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(['App','Last Updated','Current Ver'],axis=1,inplace=True)
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159   19M      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967   14M     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510  8.7M   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5   215644   25M  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3      967  2.8M     100,000+  Free     0
#
#   Content Rating                     Genres   Android Ver
# 0       Everyone               Art & Design  4.0.3 and up
# 1       Everyone  Art & Design;Pretend Play  4.0.3 and up
# ...

# %%
df_clean['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', nan],
#       dtype=object)

# %%
df_clean[df_clean['Category'].isna()]
# Out:
#       Category  Rating  Reviews  Size Installs  Type Price Content Rating  \
# 10472      NaN     1.9       19  3.0M   1,000+  Free     0            NaN
#
#          Genres Android Ver
# 10472  Everyone  4.0 and up

# %%
df_clean.drop(index=10472,inplace=True)
df_clean['Category'].unique()
# Out:
# C:\Users\Sally\AppData\Local\Temp\ipykernel_8580\3870778657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(index=10472,inplace=True)
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df_clean=df_clean.astype({'Category':'string'})
df_clean['Category']=df_clean['Category'].str.replace('_',' ')
df_clean.head()
# Out:
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART AND DESIGN     4.1      159   19M      10,000+  Free     0
# 1  ART AND DESIGN     3.9      967   14M     500,000+  Free     0
# 2  ART AND DESIGN     4.7    87510  8.7M   5,000,000+  Free     0
# 3  ART AND DESIGN     4.5   215644   25M  50,000,000+  Free     0
# 4  ART AND DESIGN     4.3      967  2.8M     100,000+  Free     0
#
#   Content Rating                     Genres   Android Ver
# 0       Everyone               Art & Design  4.0.3 and up
# 1       Everyone  Art & Design;Pretend Play  4.0.3 and up
# 2       Everyone               Art & Design  4.0.3 and up
# 3           Teen               Art & Design    4.2 and up
# 4       Everyone    Art & Design;Creativity    4.4 and up

# %%
df_clean[df_clean['Rating'].isna()]
# Out:
#                   Category  Rating  Reviews  Size  Installs  Type Price  \
# 23          ART AND DESIGN     NaN       61  7.0M  100,000+  Free     0
# 113                 BEAUTY     NaN      182  5.7M  100,000+  Free     0
# 123                 BEAUTY     NaN      119  3.7M   50,000+  Free     0
# 126                 BEAUTY     NaN      654  7.4M  100,000+  Free     0
# 129                 BEAUTY     NaN       77  2.9M   10,000+  Free     0
# ...                    ...     ...      ...   ...       ...   ...   ...
# 10824              MEDICAL     NaN       67   82M   10,000+  Free     0
# 10825               SOCIAL     NaN        7  7.7M      100+  Free     0
# 10831  MAPS AND NAVIGATION     NaN       38  9.8M    5,000+  Free     0
# 10835             BUSINESS     NaN        0  9.6M       10+  Free     0
# 10838              MEDICAL     NaN        3  9.5M    1,000+  Free     0
#
#       Content Rating                           Genres Android Ver
# ...

# %%
mode_rating=df_clean.mode()['Rating'][0]
mode_rating
df_clean['Rating']=df_clean['Rating'].fillna(mode_rating)
df_clean['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 2.5, 1. , 1.9, 2.9,
#        2.8, 2.3, 2.2, 1.7, 2. , 1.8, 2.7, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
df_clean=df_clean.astype({'Installs':'str'})
df_clean['Category']=df_clean['Category'].str.replace('_',' ')
df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Sally\Documents\Playstore_Data_Analysis\Analysis.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sally/Documents/Playstore_Data_Analysis/Analysis.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df_clean=df_clean.astype({'Installs':'str'}).astype(int)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sally/Documents/Playstore_Data_Analysis/Analysis.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> df_clean['Category']=df_clean['Category'].str.replace('_',' ')
#       <a href='vscode-notebook-cell:/c%3A/Users/Sally/Documents/Playstore_Data_Analysis/Analysis.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> df_clean.head()
#
# File c:\Users\Sally\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
# ...

# %%
df_clean['Installs']=df['Installs'].astype(str).astype(int)
df_clean.dtypes
# Out:
# Category          string[python]
# Rating                   float64
# Reviews                    int64
# Size                      object
# Installs                   int32
# Type                      object
# Price                     object
# Content Rating            object
# Genres                    object
# Android Ver               object
# dtype: object

# %%
df_clean[df_clean['Type'].isna()]
# Out:
#      Category  Rating  Reviews                Size  Installs Type Price  \
# 9148   FAMILY     4.4        0  Varies with device         0  NaN     0
#
#      Content Rating    Genres         Android Ver
# 9148   Everyone 10+  Strategy  Varies with device

# %%
df_clean['Type'].fillna('Free',inplace=True)
df_clean['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df_clean['Price']=df_clean['Price'].str.replace('$','')
df_clean['Price']=df_clean['Price'].astype(str).astype(float)
df.head()

# %%
df_clean['Price'].dtypes
# Out:
# dtype('float64')

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
#df_clean[df_clean['Content Rating'].isna()]
# Out:
# Empty DataFrame
# Columns: [Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Android Ver]
# Index: []

# %%
df_clean['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
df_clean.drop(['Genres'],axis=1,inplace=True)
df_clean.head()
# Out:
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART AND DESIGN     4.1      159   19M     10000  Free    0.0
# 1  ART AND DESIGN     3.9      967   14M    500000  Free    0.0
# 2  ART AND DESIGN     4.7    87510  8.7M   5000000  Free    0.0
# 3  ART AND DESIGN     4.5   215644   25M  50000000  Free    0.0
# 4  ART AND DESIGN     4.3      967  2.8M    100000  Free    0.0
#
#   Content Rating   Android Ver
# 0       Everyone  4.0.3 and up
# 1       Everyone  4.0.3 and up
# 2       Everyone  4.0.3 and up
# 3           Teen    4.2 and up
# 4       Everyone    4.4 and up
